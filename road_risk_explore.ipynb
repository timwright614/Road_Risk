# %%
import pandas as pd
import gmaps

# %%
casualty_df = pd.read_csv('dft-road-casualty-statistics-casualty-2020.csv')
vehicle_df = pd.read_csv('dft-road-casualty-statistics-vehicle-2020.csv', low_memory=False)
accident_df = pd.read_csv('dft-road-casualty-statistics-accident-2020.csv', low_memory=False)

# %%
casualty_df.head()
# Out:
#   accident_index  accident_year accident_reference  vehicle_reference  \
# 0  2020010219808           2020          010219808                  1
# 1  2020010220496           2020          010220496                  1
# 2  2020010220496           2020          010220496                  1
# 3  2020010228005           2020          010228005                  1
# 4  2020010228006           2020          010228006                  1
#
#    casualty_reference  casualty_class  sex_of_casualty  age_of_casualty  \
# 0                   1               3                1               31
# 1                   1               3                2                2
# 2                   2               3                2                4
# 3                   1               3                1               23
# 4                   1               3                1               47
#
#    age_band_of_casualty  casualty_severity  pedestrian_location  \
# ...

# %%
vehicle_df.head()
# Out:
#   accident_index  accident_year accident_reference  vehicle_reference  \
# 0  2020010219808           2020          010219808                  1
# 1  2020010220496           2020          010220496                  1
# 2  2020010228005           2020          010228005                  1
# 3  2020010228006           2020          010228006                  1
# 4  2020010228011           2020          010228011                  1
#
#    vehicle_type  towing_and_articulation  vehicle_manoeuvre  \
# 0             9                        9                  5
# 1             9                        0                  4
# 2             9                        0                 18
# 3             8                        0                 18
# 4             9                        0                 18
#
#    vehicle_direction_from  vehicle_direction_to  \
# 0                       1                     5
# 1                       2                     6
# ...

# %%
accident_df.head()
# Out:
#   accident_index  accident_year accident_reference  location_easting_osgr  \
# 0  2020010219808           2020          010219808               521389.0
# 1  2020010220496           2020          010220496               529337.0
# 2  2020010228005           2020          010228005               526432.0
# 3  2020010228006           2020          010228006               538676.0
# 4  2020010228011           2020          010228011               529324.0
#
#    location_northing_osgr  longitude   latitude  police_force  \
# 0                175144.0  -0.254001  51.462262             1
# 1                176237.0  -0.139253  51.470327             1
# 2                182761.0  -0.178719  51.529614             1
# 3                184371.0  -0.001683  51.541210             1
# 4                181286.0  -0.137592  51.515704             1
#
#    accident_severity  number_of_vehicles  ...  \
# 0                  3                   1  ...
# 1                  3                   1  ...
# ...

# %%
gmaps.configure(api_key = 'AIzaSyB429EwHUNNv5-AyhTse2Y3ew6IApemQAU')

# %%
central_ldn_coords = (51.50, -0.1)
fig = gmaps.figure(center=central_ldn_coords, zoom_level=11)

# %%
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
accident_coords_df = accident_df[['latitude','longitude']].dropna()

# %%
accident_coords_df
# Out:
#         latitude  longitude
# 0      51.462262  -0.254001
# 1      51.470327  -0.139253
# 2      51.529614  -0.178719
# 3      51.541210  -0.001683
# 4      51.515704  -0.137592
# ...          ...        ...
# 91194  56.473539  -2.926320
# 91195  55.802353  -4.267565
# 91196  57.186317  -2.271903
# 91197  55.950940  -3.968753
# 91198  56.003843  -4.561040
#
# [91185 rows x 2 columns]

# %%
accidents_layer = gmaps.symbol_layer(
    accident_coords_df.sample(n=5000), fill_color='green', stroke_color='green', scale=2
)

# %%
fig.add_layer(accidents_layer)

# %%
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
